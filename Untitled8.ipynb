# %% [markdown]
# <a href="https://colab.research.google.com/github/stali1234/python/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
uploaded1 = files.upload()
# Out:
#      <input type="file" id="files-6185afba-ca94-424b-8d47-c633cb8c680b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6185afba-ca94-424b-8d47-c633cb8c680b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving xdata.csv to xdata (2).csv
#      <input type="file" id="files-a2585217-5fcd-4f38-864d-7fdb7f302a94" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2585217-5fcd-4f38-864d-7fdb7f302a94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ydata.csv to ydata.csv

# %%
import io
import pandas as pd
dfx = pd.read_csv(io.BytesIO(uploaded['xdata.csv']))
dfy = pd.read_csv(io.BytesIO(uploaded1['ydata.csv']))

# %%
 x = dfx.values
 y = dfy.values
 
 x =x[:,1:]
 y = y[:,1:].reshape((-1,))
 print(x.shape , y.shape)
# Out:
# (399, 2) (399,)

# %%
plt.style.use('seaborn')
query_x = np.array([2,3])
plt.scatter(query_x[0],query_x[1] , color='red')
plt.scatter(x[:,0] , x[:,1] ,c=y)
plt.show()

# %%
 def dist(x1,x2):
   return np.sqrt((sum(x1-x2)**2))

 def knn(x,y , query_point , k=5):
   vals = []
   m = x.shape[0]

   for i in range(m):
      d = dist(query_point , x[i])
      vals.append((d,y[i]))  

   vals = sorted(vals)

   #nearest 
   vals = vals[:k]   

   vals = np.array(vals)
   return vals

# %%
vals = knn(x,y,query_x)
# Out:
# [[0.009602   0.        ]
#  [0.0207321  0.        ]
#  [0.12057373 0.        ]
#  [0.15234938 0.        ]
#  [0.1853468  0.        ]]
